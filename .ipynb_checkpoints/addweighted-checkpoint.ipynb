# %%
import cv2

# %%
img1=cv2.imread('DATA/windows.png')
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.imread('DATA/linux.png')
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.shape
# Out:
# (210, 239, 3)

# %%
img2.shape
# Out:
# (246, 205, 3)

# %%
img1=cv2.resize(img1,(200,200))
img2=cv2.resize(img2,(200,200))

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
blended=cv2.addWeighted(src1=img1,alpha=0.5,src2=img2,beta=0.5,gamma=0)
plt.imshow(blended)

# %%
#OVERLAY SMALL IMAGE ON TOPOF A LARGER IMAGE(NO BELENDING)
#NUMPY REASSIGNMENT

# %%
img1=cv2.imread('DATA/windows.png')
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.imread('DATA/linux.png')
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
img2=cv2.resize(img2,(100,100))
plt.imshow(img2)

# %%
large_img=img1
small_img=img2

# %%
x_offset=0
y_offset=0

# %%
x_end=x_offset+small_img.shape[1]
y_end=y_offset+small_img.shape[0]

# %%
small_img.shape
# Out:
# (100, 100, 3)

# %%
large_img[y_offset:y_end,x_offset:x_end]=small_img
plt.imshow(large_img)

# %%
#BELEND TO TOGETHER IMEGE OF DIFFERENDT SIZE

# %%
img1=cv2.imread('DATA/windows.png')
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.imread('DATA/linux.png')
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
img2=cv2.resize(img2,(100,100))

# %%
plt.imshow(img1)

# %%
img1.shape
# Out:
# (210, 239, 3)

# %%
x_offset=239-100
y_offset=219-100

# %%
img2.shape
# Out:
# (100, 100, 3)

# %%
rows,cols,channels=img2.shape

# %%
rows
# Out:
# 100

# %%
cols
# Out:
# 100

# %%
roi=img1[y_offset:210,x_offset:239]

# %%
plt.imshow(roi)

# %%
img2gray=cv2.cvtColor(img2,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img2gray,cmap='gray')

# %%
mask_inv=cv2.bitwise_not(img2gray)

# %%
plt.imshow(mask_inv,cmap='gray')

# %%
mask_inv.shape
# Out:
# (100, 100)

# %%
import numpy as np

# %%
white_background=np.full(img2.shape,255,dtype=np.uint8)

# %%
white_background.shape
# Out:
# (100, 100, 3)

# %%
white_background
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
bk=cv2.bitwise_or(white_background,white_background,mask=mask_inv)

# %%
bk.shape
# Out:
# (100, 100, 3)

# %%
plt.imshow(bk)

# %%
fg=cv2.bitwise_or(img2,img2,mask=mask_inv)

# %%
plt.imshow(fg)

# %%
final_roi=cv2.bitwise_or(roi,fg)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 final_roi=cv2.bitwise_or(roi,fg)
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:214: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'cv::binary_op'
