# %%
import cv2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1=cv2.imread('DATA/food.png')
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.imread('DATA/logo_opencv.png')
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
img2=cv2.resize(img2,(50,50))

# %%
plt.imshow(img1)

# %%
img1.shape
# Out:
# (194, 259, 3)

# %%
x_offset=259-50
y_offset=194-50

# %%
img2.shape
# Out:
# (50, 50, 3)

# %%
rows,cols,channels=img2.shape

# %%
rows
# Out:
# 50

# %%
cols
# Out:
# 50

# %%
roi=img1[y_offset:194,x_offset:259]

# %%
roi.shape
# Out:
# (50, 50, 3)

# %%
plt.imshow(roi)

# %%
img2gray=cv2.cvtColor(img2,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img2gray,cmap='gray')

# %%
mask_inv=cv2.bitwise_not(img2gray)

# %%
plt.imshow(mask_inv,cmap='gray')

# %%
mask_inv.shape
# Out:
# (50, 50)

# %%
import numpy as np

# %%
white_background=np.full(img2.shape,255,dtype=np.uint8)

# %%
white_background.shape
# Out:
# (50, 50, 3)

# %%
white_background
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
bk=cv2.bitwise_or(white_background,white_background,mask=mask_inv)

# %%
bk.shape
# Out:
# (50, 50, 3)

# %%
plt.imshow(bk)

# %%
fg=cv2.bitwise_or(img2,img2,mask=mask_inv)

# %%
plt.imshow(fg)

# %%
fg.shape
# Out:
# (50, 50, 3)

# %%
final_roi=cv2.bitwise_or(roi,fg)

# %%
plt.imshow(final_roi)

# %%
large_img=img1
small_img=final_roi

# %%
large_img[y_offset:y_offset + small_img.shape[0],x_offset:x_offset + small_img.shape[1]]=small_img

# %%
plt.imshow(large_img)
