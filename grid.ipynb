# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flat_chess=cv2.imread('DATA/flat_chessboard.jpg')
plt.imshow(flat_chess)

# %%
found,corners=cv2.findChessboardCorners(flat_chess,(7,7))

# %%
found
# Out:
# True

# %%
corners
# Out:
# array([[[ 64.57445 ,  64.337326]],
#
#        [[102.5     ,  63.      ]],
#
#        [[141.07057 ,  63.39022 ]],
#
#        [[179.57101 ,  63.505157]],
#
#        [[217.9674  ,  62.926586]],
#
#        [[254.01158 ,  61.62079 ]],
#
#        [[294.7172  ,  62.710125]],
#
#        [[ 65.13403 , 101.50225 ]],
#
#        [[103.26618 , 100.44703 ]],
#
#        [[141.77963 , 101.88583 ]],
#
#        [[179.86562 , 100.27056 ]],
#
#        [[217.37627 , 100.53618 ]],
#
#        [[255.20679 , 101.42567 ]],
#
#        [[294.2904  , 101.25448 ]],
#
#        [[ 65.24349 , 138.3496  ]],
#
#        [[103.2799  , 139.38016 ]],
#
#        [[140.53127 , 139.83725 ]],
#
#        [[179.68684 , 139.59926 ]],
#
#        [[217.72552 , 139.17479 ]],
#
#        [[256.32993 , 138.94478 ]],
#
#        [[292.86978 , 139.82759 ]],
#
#        [[ 64.89777 , 178.46152 ]],
#
#        [[103.100136, 177.3537  ]],
#
#        [[141.47034 , 177.72307 ]],
#
#        [[179.69984 , 176.92961 ]],
#
#        [[216.78102 , 176.28613 ]],
#
#        [[257.03696 , 176.50183 ]],
#
#        [[294.57062 , 177.4775  ]],
#
#        [[ 64.56274 , 216.1603  ]],
#
#        [[102.76517 , 214.5706  ]],
#
#        [[142.2956  , 214.83127 ]],
#
#        [[179.07405 , 214.8891  ]],
#
#        [[217.62193 , 215.06367 ]],
#
#        [[256.09818 , 215.1545  ]],
#
#        [[294.44482 , 215.04982 ]],
#
#        [[ 64.31628 , 253.33887 ]],
#
#        [[103.20499 , 253.72981 ]],
#
#        [[141.51865 , 254.8144  ]],
#
#        [[179.91684 , 253.62567 ]],
#
#        [[217.74802 , 253.75696 ]],
#
#        [[255.65681 , 254.19444 ]],
#
#        [[294.7485  , 253.71075 ]],
#
#        [[ 64.86208 , 292.31735 ]],
#
#        [[102.40767 , 292.62384 ]],
#
#        [[141.054   , 292.35696 ]],
#
#        [[179.2084  , 292.0967  ]],
#
#        [[217.49576 , 291.43863 ]],
#
#        [[255.97444 , 292.22406 ]],
#
#        [[294.86722 , 291.78604 ]]], dtype=float32)

# %%
cv2.drawChessboardCorners(flat_chess,(7,7),corners,found)
# Out:
# array([[[107, 175, 218],
#         [102, 170, 213],
#         [ 97, 165, 208],
#         ...,
#         [ 72, 134, 182],
#         [ 66, 125, 174],
#         [ 69, 128, 177]],
#
#        [[109, 177, 220],
#         [104, 172, 215],
#         [100, 168, 211],
#         ...,
#         [ 71, 133, 181],
#         [ 68, 127, 176],
#         [ 72, 131, 180]],
#
#        [[108, 176, 219],
#         [106, 174, 217],
#         [105, 170, 214],
#         ...,
#         [ 71, 133, 181],
#         [ 72, 131, 180],
#         [ 76, 135, 184]],
#
#        ...,
#
#        [[ 96, 150, 191],
#         [ 96, 150, 191],
#         [105, 159, 200],
#         ...,
#         [ 95, 148, 191],
#         [ 98, 151, 194],
#         [ 97, 150, 193]],
#
#        [[ 99, 153, 194],
#         [ 97, 151, 192],
#         [106, 160, 201],
#         ...,
#         [ 98, 151, 194],
#         [ 98, 151, 194],
#         [ 97, 150, 193]],
#
#        [[ 95, 149, 190],
#         [ 92, 146, 187],
#         [100, 154, 195],
#         ...,
#         [105, 158, 201],
#         [102, 155, 198],
#         [101, 154, 197]]], dtype=uint8)

# %%
plt.imshow(flat_chess)

# %%
dots=cv2.imread('DATA/dots_grid.png')

# %%
plt.imshow(dots)

# %%
found,corners=cv2.findCirclesGrid(dots,(10,10),cv2.CALIB_CB_SYMMETRIC_GRID)

# %%
found
# Out:
# True

# %%
corners
# Out:
# array([[[ 20.752987,  29.758453]],
#
#        [[109.51112 ,  29.755722]],
#
#        [[198.27098 ,  29.751871]],
#
#        [[287.04736 ,  29.75608 ]],
#
#        [[375.86734 ,  29.74928 ]],
#
#        [[464.63016 ,  29.746956]],
#
#        [[553.37036 ,  29.74771 ]],
#
#        [[642.1518  ,  29.751972]],
#
#        [[730.9433  ,  29.75471 ]],
#
#        [[819.7409  ,  29.757315]],
#
#        [[ 20.752562, 118.513214]],
#
#        [[109.516014, 118.517944]],
#
#        [[198.27261 , 118.51192 ]],
#
#        [[287.05182 , 118.510155]],
#
#        [[375.8521  , 118.50857 ]],
#
#        [[464.6194  , 118.51536 ]],
#
#        [[553.3803  , 118.520836]],
#
#        [[642.1418  , 118.514755]],
#
#        [[730.9503  , 118.50357 ]],
#
#        [[819.7264  , 118.49905 ]],
#
#        [[ 20.754833, 207.2671  ]],
#
#        [[109.51171 , 207.26707 ]],
#
#        [[198.2688  , 207.27132 ]],
#
#        [[287.0628  , 207.2829  ]],
#
#        [[375.83618 , 207.27713 ]],
#
#        [[464.61896 , 207.27228 ]],
#
#        [[553.38306 , 207.26611 ]],
#
#        [[642.1481  , 207.26811 ]],
#
#        [[730.9577  , 207.27596 ]],
#
#        [[819.72015 , 207.27634 ]],
#
#        [[ 20.751606, 296.05353 ]],
#
#        [[109.51294 , 296.05832 ]],
#
#        [[198.27428 , 296.05133 ]],
#
#        [[287.06647 , 296.05893 ]],
#
#        [[375.84116 , 296.05502 ]],
#
#        [[464.62152 , 296.05246 ]],
#
#        [[553.37695 , 296.059   ]],
#
#        [[642.1522  , 296.0539  ]],
#
#        [[730.9369  , 296.0576  ]],
#
#        [[819.72705 , 296.05112 ]],
#
#        [[ 20.744833, 384.85153 ]],
#
#        [[109.51029 , 384.85748 ]],
#
#        [[198.27419 , 384.85056 ]],
#
#        [[287.05435 , 384.8384  ]],
#
#        [[375.85425 , 384.846   ]],
#
#        [[464.63162 , 384.84937 ]],
#
#        [[553.3741  , 384.8581  ]],
#
#        [[642.15436 , 384.84412 ]],
#
#        [[730.93976 , 384.8501  ]],
#
#        [[819.73254 , 384.8444  ]],
#
#        [[ 20.74759 , 473.62375 ]],
#
#        [[109.51368 , 473.61215 ]],
#
#        [[198.27771 , 473.62335 ]],
#
#        [[287.04782 , 473.6271  ]],
#
#        [[375.86798 , 473.6309  ]],
#
#        [[464.6265  , 473.62192 ]],
#
#        [[553.37634 , 473.61816 ]],
#
#        [[642.14935 , 473.6235  ]],
#
#        [[730.9457  , 473.6286  ]],
#
#        [[819.73315 , 473.62735 ]],
#
#        [[ 20.752464, 562.37146 ]],
#
#        [[109.516495, 562.3751  ]],
#
#        [[198.26794 , 562.37775 ]],
#
#        [[287.0552  , 562.3786  ]],
#
#        [[375.85385 , 562.3817  ]],
#
#        [[464.6276  , 562.3791  ]],
#
#        [[553.37726 , 562.3703  ]],
#
#        [[642.14325 , 562.3782  ]],
#
#        [[730.9482  , 562.38184 ]],
#
#        [[819.73016 , 562.3748  ]],
#
#        [[ 20.750805, 651.1485  ]],
#
#        [[109.51465 , 651.14044 ]],
#
#        [[198.26907 , 651.1475  ]],
#
#        [[287.0627  , 651.1532  ]],
#
#        [[375.8427  , 651.15137 ]],
#
#        [[464.6203  , 651.1424  ]],
#
#        [[553.37933 , 651.14636 ]],
#
#        [[642.1489  , 651.1466  ]],
#
#        [[730.9545  , 651.1572  ]],
#
#        [[819.72015 , 651.1471  ]],
#
#        [[ 20.75434 , 739.94904 ]],
#
#        [[109.513214, 739.9531  ]],
#
#        [[198.27484 , 739.9403  ]],
#
#        [[287.0601  , 739.9403  ]],
#
#        [[375.84573 , 739.9435  ]],
#
#        [[464.62405 , 739.94745 ]],
#
#        [[553.3784  , 739.9476  ]],
#
#        [[642.1549  , 739.9424  ]],
#
#        [[730.94037 , 739.9468  ]],
#
#        [[819.73083 , 739.9563  ]],
#
#        [[ 20.750319, 828.7307  ]],
#
#        [[109.50821 , 828.72754 ]],
#
#        [[198.27388 , 828.7304  ]],
#
#        [[287.04712 , 828.7322  ]],
#
#        [[375.85745 , 828.7301  ]],
#
#        [[464.62354 , 828.72284 ]],
#
#        [[553.3705  , 828.73126 ]],
#
#        [[642.14966 , 828.72925 ]],
#
#        [[730.9416  , 828.7266  ]],
#
#        [[819.7433  , 828.73566 ]]], dtype=float32)

# %%
cv2.drawChessboardCorners(dots,(10,10),corners,found)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]]], dtype=uint8)

# %%
plt.imshow(dots)
